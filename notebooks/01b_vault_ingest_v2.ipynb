# %%
import os
import json
import re
import warnings

import pandas as pd
import numpy as np
import osc_ingest_trino as osc
import trino

import ITR
from ITR import data_dir as json_data_dir
from ITR_examples import data_dir as xlsx_data_dir

from ITR.configs import ITR_median, ITR_mean, LoggingConfig
from ITR.data.base_providers import BaseProviderProductionBenchmark, BaseProviderIntensityBenchmark
from ITR.data.data_warehouse import DataWarehouse
from ITR.data.osc_units import ureg, Q_, PA_, asPintSeries
from ITR.data.template import TemplateProviderCompany
from ITR.data.vault_providers import (
    VaultCompanyDataProvider,
    create_table_from_df,
)
from ITR.interfaces import (
    EScope,
    ETimeFrames,
    EScoreResultType,
    IEIBenchmarkScopes,
    IProductionBenchmarkScopes,
    ProjectionControls,
)
from ITR.portfolio_aggregation import PortfolioAggregationMethod
from ITR.temperature_score import TemperatureScore

# isort: split

import logging

ingest_catalog = "osc_datacommons_dev"
ingest_schema = "demo_dv"
itr_prefix = "itr_"

osc.load_credentials_dotenv()

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

formatter = logging.Formatter("%(asctime)s - %(name)s - %(levelname)s - %(message)s")  # LoggingConfig.FORMAT
stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
logger.addHandler(stream_handler)

logger.info("Start!")

company_data_path = os.path.join(xlsx_data_dir, "20220927 ITR V2 Sample Data.xlsx")

# Production benchmark (there's only one, and we have to stretch it from OECM to cover TPI)
benchmark_prod_json_file = "benchmark_production_OECM.json"
benchmark_prod_json = os.path.join(json_data_dir, benchmark_prod_json_file)
with open(benchmark_prod_json) as json_file:
    parsed_json = json.load(json_file)

prod_bms = IProductionBenchmarkScopes.model_validate(parsed_json)
base_production_bm = BaseProviderProductionBenchmark(production_benchmarks=prod_bms)
logger.info("Load production benchmark from {}".format(benchmark_prod_json_file))

# Emission intensities
benchmark_EI_OECM_PC_file = "benchmark_EI_OECM_PC.json"
benchmark_EI_OECM_S3_file = "benchmark_EI_OECM_S3.json"
benchmark_EI_OECM_file = "benchmark_EI_OECM.json"  # Deprecated!
benchmark_EI_TPI_15_file = "benchmark_EI_TPI_1_5_degrees.json"
benchmark_EI_TPI_file = "benchmark_EI_TPI_2_degrees.json"
benchmark_EI_TPI_below_2_file = "benchmark_EI_TPI_below_2_degrees.json"
benchmark_EI_TPI_2deg_high_efficiency_file = "benchmark_EI_TPI_2_degrees_high_efficiency.json"
benchmark_EI_TPI_2deg_shift_improve_file = "benchmark_EI_TPI_2_degrees_shift_improve.json"
# Out:
# 2023-12-01 15:08:09,521 - __main__ - INFO - Start!
# 2023-12-01 15:08:09,714 - __main__ - INFO - Load production benchmark from benchmark_production_OECM.json

# %%
# loading sample portfolio
df_portfolio = pd.read_excel(company_data_path, sheet_name="Portfolio")

for i, col in enumerate(df_portfolio.columns):
    if col.startswith("investment_value"):
        if match := re.match(r".*\[([A-Z]{3})\]", col, re.I):
            df_portfolio.rename(columns={col: "investment_value"}, inplace=True)
            df_portfolio["investment_value"] = df_portfolio["investment_value"].astype(f"pint[{match.group(1)}]")

# %%
eibm = "OECM_S3"

if eibm == "OECM_PC":
    benchmark_file = benchmark_EI_OECM_PC_file
elif eibm == "OECM_S3":
    benchmark_file = benchmark_EI_OECM_S3_file
elif eibm.startswith("TPI_2_degrees"):
    benchmark_file = benchmark_EI_TPI_file
elif eibm == "TPI_15_degrees":
    benchmark_file = benchmark_EI_TPI_15_file
elif eibm == "OECM":
    benchmark_file = benchmark_EI_OECM_file
    logger.info("OECM benchmark is for backward compatibility only.  Use OECM_PC instead.")
else:
    benchmark_file = benchmark_EI_TPI_below_2_file
# load intensity benchmarks
benchmark_EI = os.path.join(json_data_dir, benchmark_file)
with open(benchmark_EI) as json_file:
    parsed_json = json.load(json_file)
if eibm.startswith("TPI_2_degrees"):
    extra_EI = os.path.join(
        json_data_dir,
        (
            benchmark_EI_TPI_2deg_high_efficiency_file
            if "_high_efficiency" in eibm
            else benchmark_EI_TPI_2deg_shift_improve_file
        ),
    )
    with open(extra_EI) as json_file:
        extra_json = json.load(json_file)
        for scope_name in EScope.get_scopes():
            if scope_name in extra_json:
                if scope_name not in parsed_json:
                    parsed_json[scope_name] = extra_json[scope_name]
                else:
                    parsed_json[scope_name]["benchmarks"] += extra_json[scope_name]["benchmarks"]
EI_bm = BaseProviderIntensityBenchmark(EI_benchmarks=IEIBenchmarkScopes.model_validate(parsed_json))

# %%
# We fill a conventional DataWarehouse with template data
# After the ingestion process is complete, downstream users can access DataVaultWarehouse

template_company_data = TemplateProviderCompany(company_data_path, projection_controls=ProjectionControls())
Warehouse = DataWarehouse(
    template_company_data,
    benchmark_projected_production=base_production_bm,
    benchmarks_projected_ei=EI_bm,
    estimate_missing_data=DataWarehouse.estimate_missing_s3_data,
)
# Out:
# 2023-12-01 15:08:15,125 - ITR.data.template - WARNING - Company DE0005190003 uses multiple units describing scopes ['s3']
# 2023-12-01 15:08:15,126 - ITR.data.template - WARNING - Company US00130H1059 uses multiple units describing scopes ['s1', 's1s2', 's2', 's3']
# 2023-12-01 15:08:15,126 - ITR.data.template - WARNING - The ITR Tool will choose one and covert all to that
# 2023-12-01 15:08:15,900 - ITR.data.template - WARNING - Emissions data missing for MultiIndex([('Energy', 'PETRONAS_SOE', 'S1'),
#             ('Energy', 'PETRONAS_SOE', 'S2')],
#            names=['sector', 'company_id', 'metric'])
# 2023-12-01 15:08:15,956 - ITR.data.template - WARNING - Scope 3 Emissions data missing for MultiIndex([('Construction Buildings', 'GB0000961622'),
#             ( 'Electricity Utilities', 'CA2908761018'),
#             ( 'Electricity Utilities', 'CA3495531079'),
#             ( 'Electricity Utilities', 'CA87807B1076'),
#             ( 'Electricity Utilities', 'US0185223007'),
#             ( 'Electricity Utilities', 'US0188021085'),
#             ( 'Electricity Utilities', 'US0236081024'),
#             ( 'Electricity Utilities', 'US0255371017'),
#             ( 'Electricity Utilities', 'US0921131092'),
#             ( 'Electricity Utilities', 'US1258961002'),
#             ( 'Electricity Utilities', 'US18551QAA58'),
#             ( 'Electricity Utilities', 'US2091151041'),
#             ( 'Electricity Utilities', 'US2333311072'),
#             ( 'Electricity Utilities', 'US25746U1097'),
#             ( 'Electricity Utilities', 'US26441C2044'),
#             ( 'Electricity Utilities', 'US29364G1031'),
#             ( 'Electricity Utilities', 'US30034W1062'),
#             ( 'Electricity Utilities', 'US30040W1080'),
#             ( 'Electricity Utilities', 'US30161N1019'),
#             ( 'Electricity Utilities', 'US3379321074'),
#             ( 'Electricity Utilities', 'US4198701009'),
#             ( 'Electricity Utilities', 'US5526901096'),
#             ( 'Electricity Utilities', 'US6362744095'),
#             ( 'Electricity Utilities', 'US65339F1012'),
#             ( 'Electricity Utilities', 'US65473P1057'),
#             ( 'Electricity Utilities', 'US6680743050'),
#             ( 'Electricity Utilities', 'US6708371033'),
#             ( 'Electricity Utilities', 'US69331C1080'),
#             ( 'Electricity Utilities', 'US69349H1077'),
#             ( 'Electricity Utilities', 'US69351T1060'),
#             ( 'Electricity Utilities', 'US7234841010'),
#             ( 'Electricity Utilities', 'US7365088472'),
#             ( 'Electricity Utilities', 'US7445731067'),
#             ( 'Electricity Utilities', 'US8168511090'),
#             ( 'Electricity Utilities', 'US8425871071'),
#             ( 'Electricity Utilities', 'US92939U1060'),
#             ( 'Electricity Utilities', 'US98389B1008'),
#             (                'Energy', 'PETRONAS_SOE'),
#             (                 'Steel', 'US1442851036'),
#             (                 'Steel', 'US2017231034'),
#             (                 'Steel', 'US3737371050'),
#             (                 'Steel', 'US8581191009'),
#             (                 'Steel', 'US9129091081'),
#             (                 'Steel', 'US9818111026')],
#            names=['sector', 'company_id'])
# 2023-12-01 15:08:16,680 - ITR.data.template - WARNING - Missing target start year set to 2021 for companies with ID: ['US0185223007', 'US0188021085', 'US0236081024', 'US0255371017', 'US05351W1036-E', 'US05351W1036-U', 'US0921131092', 'US1442851036', 'US18551QAA58', 'US25746U1097', 'US26441C2044', 'US30034W1062', 'US5526901096', 'JP3633400001']
# 2023-12-01 15:08:19,095 - ITR.data.data_warehouse - INFO - new_production_bm calculating trajectories for 76companies (times 5 scopes times 31 years)
# 2023-12-01 15:08:20,948 - ITR.data.base_providers - INFO - Normalizing intensity metrics
# 2023-12-01 15:08:21,092 - ITR.data.base_providers - INFO - Done normalizing intensity metrics
# 2023-12-01 15:08:21,093 - ITR.data.data_warehouse - INFO - estimating missing data
# 2023-12-01 15:08:21,096 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0185223007 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,098 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0188021085 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,101 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0236081024 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,103 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0255371017 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,107 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0921131092 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,112 - ITR.data.data_warehouse - INFO - Added S3 estimates for US1442851036 (sector = Steel, region = North America)
# 2023-12-01 15:08:21,115 - ITR.data.data_warehouse - INFO - Added S3 estimates for US1258961002 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,118 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2017231034 (sector = Steel, region = North America)
# 2023-12-01 15:08:21,121 - ITR.data.data_warehouse - INFO - Added S3 estimates for US18551QAA58 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,124 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2091151041 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,127 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2333311072 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,130 - ITR.data.data_warehouse - INFO - Added S3 estimates for US25746U1097 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,133 - ITR.data.data_warehouse - INFO - Added S3 estimates for US26441C2044 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,136 - ITR.data.data_warehouse - INFO - Added S3 estimates for US29364G1031 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,139 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30034W1062 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,143 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30040W1080 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,146 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30161N1019 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,149 - ITR.data.data_warehouse - INFO - Added S3 estimates for US3379321074 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,152 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA3495531079 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,155 - ITR.data.data_warehouse - INFO - Added S3 estimates for US3737371050 (sector = Steel, region = Global)
# 2023-12-01 15:08:21,158 - ITR.data.data_warehouse - INFO - Added S3 estimates for US4198701009 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,162 - ITR.data.data_warehouse - INFO - Added S3 estimates for US5526901096 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,165 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6362744095 (sector = Electricity Utilities, region = Europe)
# 2023-12-01 15:08:21,168 - ITR.data.data_warehouse - INFO - Added S3 estimates for US65339F1012 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,171 - ITR.data.data_warehouse - INFO - Added S3 estimates for US65473P1057 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,174 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6680743050 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,177 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6708371033 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,180 - ITR.data.data_warehouse - INFO - Added S3 estimates for PETRONAS_SOE (sector = Energy, region = Global)
# 2023-12-01 15:08:21,184 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69331C1080 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,187 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69349H1077 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,190 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69351T1060 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,193 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7234841010 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,196 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7365088472 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,199 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7445731067 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,202 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8168511090 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,205 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8425871071 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,208 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8581191009 (sector = Steel, region = North America)
# 2023-12-01 15:08:21,213 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA87807B1076 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,222 - ITR.data.data_warehouse - INFO - Added S3 estimates for US9129091081 (sector = Steel, region = North America)
# 2023-12-01 15:08:21,227 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA2908761018 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,230 - ITR.data.data_warehouse - INFO - Added S3 estimates for US92939U1060 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,235 - ITR.data.data_warehouse - INFO - Added S3 estimates for US9818111026 (sector = Steel, region = North America)
# 2023-12-01 15:08:21,239 - ITR.data.data_warehouse - INFO - Added S3 estimates for US98389B1008 (sector = Electricity Utilities, region = North America)
# 2023-12-01 15:08:21,244 - ITR.data.data_warehouse - INFO - Added S3 estimates for GB0000961622 (sector = Construction Buildings, region = Europe)
# 2023-12-01 15:08:21,245 - ITR.data.data_warehouse - INFO - projecting targets for 76 companies (times 5 scopes times 31 years)

# %% [raw]
# print("Initializing Dev tables")
#
# sqlstring = "trino://{user}@{host}:{port}/".format(
#     user=os.environ["TRINO_USER_USER1"], host=os.environ["TRINO_HOST"], port=os.environ["TRINO_PORT"]
# )
#
# sqlargs = {
#     "auth": trino.auth.JWTAuthentication(os.environ["TRINO_PASSWD_USER1"]),
#     "http_scheme": "https",
#     "catalog": ingest_catalog,
#     "schema": ingest_schema,
# }
#
# ingest_engine = create_engine(sqlstring, connect_args=sqlargs)
# print("connecting with engine " + str(dev_engine))
# qres = osc._do_sql(f"show tables in {ingest_schema}", ingest_engine, verbose=True)

# %%
# This will have identity of main notebook user, not OS-Climate-User1
ingest_engine = osc.attach_trino_engine(verbose=True, catalog=ingest_catalog, schema=ingest_schema)
# Out:
# using connect string: trino://MichaelTiemannOSC@trino-secure-odh-trino.apps.odh-cl2.apps.os-climate.org:443/osc_datacommons_dev/demo_dv

# %%
# bucket must be configured with credentials for trino, and accessible to the hive catalog
# You may need to use a different prefix here depending on how you name your credentials.env variables
hive_bucket = osc.attach_s3_bucket("S3_OSCCL2")

hive_catalog = "osc_datacommons_hive_ingest"
hive_schema = "ingest"

# %% [markdown]
# ## ITR Company Data

# %%
fundamental_cols = [
    "company_name",
    "company_lei",
    "company_id",
    "sector",
    "country",
    "region",
    "exposure",
    "currency",
    "report_date",
    "company_market_cap",
    "company_revenue",
    "company_enterprise_value",
    "company_ev_plus_cash",
    "company_total_assets",
    "cash",
    "debt",
]

for col in ["cash", "debt"]:
    if col not in template_company_data.df_fundamentals.columns:
        template_company_data.df_fundamentals[col] = np.nan * template_company_data.df_fundamentals["company_revenue"]

df = template_company_data.df_fundamentals[fundamental_cols].copy()

df.rename(
    columns={
        "company_enterprise_value": "company_ev",
        "company_ev_plus_cash": "company_evic",
        "cash": "company_cash_equivalents",
        "debt": "company_debt",
    },
    inplace=True,
)
df["year"] = df.report_date.dt.year
df.drop(columns="report_date", inplace=True)

company_tablename = f"{itr_prefix}company_data"

# ingest company data
create_table_from_df(
    df, ingest_schema, company_tablename, ingest_engine, hive_bucket, hive_catalog, hive_schema, verbose=True
)
# Out:
# drop table if exists demo_dv.itr_company_data
# enforcing dataframe partition column order
#
# verifying existence of table demo_dv.itr_company_data
# create table if not exists demo_dv.itr_company_data (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     country varchar,
#     region varchar,
#     exposure varchar,
#     currency varchar,
#     company_market_cap double,
#     company_market_cap_units varchar,
#     company_revenue double,
#     company_revenue_units varchar,
#     company_ev double,
#     company_ev_units varchar,
#     company_evic double,
#     company_evic_units varchar,
#     company_total_assets double,
#     company_total_assets_units varchar,
#     company_cash_equivalents bigint,
#     company_cash_equivalents_units varchar,
#     company_debt bigint,
#     company_debt_units varchar,
#     year integer
# ) with (
#     format = 'parquet',
#     partitioning = array['year']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_7b804f17/_common_metadata  -->  trino/ingest/ingest_temp_7b804f17/_common_metadata
# /tmp/ingest_temp_7b804f17/_metadata  -->  trino/ingest/ingest_temp_7b804f17/_metadata
# /tmp/ingest_temp_7b804f17/year=2020/part.0.parquet  -->  trino/ingest/ingest_temp_7b804f17/year=2020/part.0.parquet
# /tmp/ingest_temp_7b804f17/year=2019/part.0.parquet  -->  trino/ingest/ingest_temp_7b804f17/year=2019/part.0.parquet
# /tmp/ingest_temp_7b804f17/year=2021/part.0.parquet  -->  trino/ingest/ingest_temp_7b804f17/year=2021/part.0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_7b804f17
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_7b804f17 (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     country varchar,
#     region varchar,
#     exposure varchar,
#     currency varchar,
#     company_market_cap double,
#     company_market_cap_units varchar,
#     company_revenue double,
#     company_revenue_units varchar,
#     company_ev double,
#     company_ev_units varchar,
#     company_evic double,
#     company_evic_units varchar,
#     company_total_assets double,
#     company_total_assets_units varchar,
#     company_cash_equivalents bigint,
#     company_cash_equivalents_units varchar,
#     company_debt bigint,
#     company_debt_units varchar,
#     year integer
# ) with (
#     format = 'parquet',
#     partitioned_by = array['year'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_7b804f17/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_7b804f17', 'FULL')
#
# overwriting data in demo_dv.itr_company_data
# delete from demo_dv.itr_company_data
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_7b804f17 -> demo_dv.itr_company_data
# insert into demo_dv.itr_company_data
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_7b804f17
# [(76,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_7b804f17
# [{'ResponseMetadata': {'RequestId': 'YFKA8GSVAYVH1KWA', 'HostId': 'Est4p3slyuBLy/v0vuK+bYotV3jhCZkINxPIftbTa8lsQbpzSfAe+m0BUiL8YfG6KWI73kgDhMY=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Est4p3slyuBLy/v0vuK+bYotV3jhCZkINxPIftbTa8lsQbpzSfAe+m0BUiL8YfG6KWI73kgDhMY=', 'x-amz-request-id': 'YFKA8GSVAYVH1KWA', 'date': 'Fri, 01 Dec 2023 02:08:39 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_7b804f17/year=2021/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_7b804f17/year=2020/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_7b804f17/_common_metadata'}, {'Key': 'trino/ingest/ingest_temp_7b804f17/year=2019/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_7b804f17/_metadata'}]}]

# %%
company_info_at_base_year = template_company_data.get_company_intensity_and_production_at_base_year(
    [
        company_id
        for company_id in template_company_data.df_fundamentals.company_id.values
        if company_id != "US6745991058-chem"
    ]
)

import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # See https://github.com/hgrecco/pint-pandas/issues/128
    projected_production = Warehouse.benchmark_projected_production.get_company_projected_production(
        company_info_at_base_year
    )

# %%
type(projected_production.iloc[0, 0])
# Out:
# pint.Quantity

# %%
company_data = VaultCompanyDataProvider(ingest_engine, company_tablename)

production_tablename = f"{itr_prefix}production_data"

df = projected_production.droplevel("scope").drop_duplicates()
df.columns.set_names("year", inplace=True)
df2 = df.unstack(level=0).to_frame("production_by_year").reset_index("year")
df3 = pd.read_sql(
    f"select distinct company_id, company_name, company_lei, sector from {company_data._company_table}", ingest_engine
)
df4 = df2.merge(df3, on="company_id").reset_index()
production_df = df4[
    # Reorder columns
    [
        "company_name",
        "company_lei",
        "company_id",
        "sector",
        "year",
        "production_by_year",
    ]
]

# Ingest productions into Data Vault
create_table_from_df(
    production_df,
    ingest_schema,
    company_data._production_table,
    ingest_engine,
    hive_bucket,
    hive_catalog,
    hive_schema,
    verbose=True,
)
# Out:
# drop table if exists demo_dv.itr_production_data
# /Users/michael/virtualenvs/itr-examples/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:225: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return _isna_array(np.asarray(obj), inf_as_na=inf_as_na)
# enforcing dataframe partition column order
#
# verifying existence of table demo_dv.itr_production_data
# create table if not exists demo_dv.itr_production_data (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     production_by_year double,
#     production_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioning = array['year']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_21613342/_common_metadata  -->  trino/ingest/ingest_temp_21613342/_common_metadata
# /tmp/ingest_temp_21613342/_metadata  -->  trino/ingest/ingest_temp_21613342/_metadata
# /tmp/ingest_temp_21613342/year=2032/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2032/part.0.parquet
# /tmp/ingest_temp_21613342/year=2035/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2035/part.0.parquet
# /tmp/ingest_temp_21613342/year=2050/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2050/part.0.parquet
# /tmp/ingest_temp_21613342/year=2034/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2034/part.0.parquet
# /tmp/ingest_temp_21613342/year=2033/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2033/part.0.parquet
# /tmp/ingest_temp_21613342/year=2042/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2042/part.0.parquet
# /tmp/ingest_temp_21613342/year=2045/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2045/part.0.parquet
# /tmp/ingest_temp_21613342/year=2020/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2020/part.0.parquet
# /tmp/ingest_temp_21613342/year=2027/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2027/part.0.parquet
# /tmp/ingest_temp_21613342/year=2029/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2029/part.0.parquet
# /tmp/ingest_temp_21613342/year=2044/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2044/part.0.parquet
# /tmp/ingest_temp_21613342/year=2043/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2043/part.0.parquet
# /tmp/ingest_temp_21613342/year=2028/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2028/part.0.parquet
# /tmp/ingest_temp_21613342/year=2026/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2026/part.0.parquet
# /tmp/ingest_temp_21613342/year=2019/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2019/part.0.parquet
# /tmp/ingest_temp_21613342/year=2021/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2021/part.0.parquet
# /tmp/ingest_temp_21613342/year=2038/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2038/part.0.parquet
# /tmp/ingest_temp_21613342/year=2036/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2036/part.0.parquet
# /tmp/ingest_temp_21613342/year=2031/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2031/part.0.parquet
# /tmp/ingest_temp_21613342/year=2030/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2030/part.0.parquet
# /tmp/ingest_temp_21613342/year=2037/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2037/part.0.parquet
# /tmp/ingest_temp_21613342/year=2039/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2039/part.0.parquet
# /tmp/ingest_temp_21613342/year=2024/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2024/part.0.parquet
# /tmp/ingest_temp_21613342/year=2023/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2023/part.0.parquet
# /tmp/ingest_temp_21613342/year=2046/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2046/part.0.parquet
# /tmp/ingest_temp_21613342/year=2041/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2041/part.0.parquet
# /tmp/ingest_temp_21613342/year=2048/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2048/part.0.parquet
# /tmp/ingest_temp_21613342/year=2022/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2022/part.0.parquet
# /tmp/ingest_temp_21613342/year=2025/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2025/part.0.parquet
# /tmp/ingest_temp_21613342/year=2049/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2049/part.0.parquet
# /tmp/ingest_temp_21613342/year=2040/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2040/part.0.parquet
# /tmp/ingest_temp_21613342/year=2047/part.0.parquet  -->  trino/ingest/ingest_temp_21613342/year=2047/part.0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_21613342
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_21613342 (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     production_by_year double,
#     production_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioned_by = array['year'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_21613342/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_21613342', 'FULL')
#
# overwriting data in demo_dv.itr_production_data
# delete from demo_dv.itr_production_data
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_21613342 -> demo_dv.itr_production_data
# insert into demo_dv.itr_production_data
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_21613342
# [(2432,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_21613342
# [{'ResponseMetadata': {'RequestId': 'FM4S701BMZG7Y7MK', 'HostId': 'eigZpuoeVfmF6nUI289YRfDEDahA40wg01gWpqs8Az5KlReOuOKLWcOAxyF5bGJ0jPq0NhZu7xM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'eigZpuoeVfmF6nUI289YRfDEDahA40wg01gWpqs8Az5KlReOuOKLWcOAxyF5bGJ0jPq0NhZu7xM=', 'x-amz-request-id': 'FM4S701BMZG7Y7MK', 'date': 'Fri, 01 Dec 2023 02:15:24 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_21613342/year=2045/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2032/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2031/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2042/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2019/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2050/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2029/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2037/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2021/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2034/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2024/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2025/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2040/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2041/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2039/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2026/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2030/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2044/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2047/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2022/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2036/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2038/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2046/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2048/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2049/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/_common_metadata'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2023/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/_metadata'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2028/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2043/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2033/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2035/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2020/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_21613342/year=2027/part.0.parquet'}]}]

# %%
target_tablename = f"{itr_prefix}target_data"
trajectory_tablename = f"{itr_prefix}trajectory_data"

target_dfs = []
trajectory_dfs = []
projection_tablename = [target_tablename, trajectory_tablename]

for i, projection in enumerate(["projected_targets", "projected_intensities"]):
    projection_dfs = []
    for company in template_company_data._companies:
        ei_dict = {}
        for scope in EScope.get_scopes():
            if getattr(company, projection)[scope]:
                ei_dict[scope] = getattr(company, projection)[scope].projections
            else:
                ei_dict[scope] = pd.Series(dtype="object")
        ei_data = pd.concat([ei_dict[scope] for scope in EScope.get_scopes()], axis=1).reset_index()
        ei_data.columns = ["year"] + [f"ei_{scope.lower()}_by_year" for scope in EScope.get_scopes()]
        df = pd.DataFrame(
            data=[[company.company_name, "", company.company_id, company.sector] for i in ei_data.index],
            columns=["company_name", "company_lei", "company_id", "sector"],
        )
        projection_dfs.append(pd.concat([df, ei_data], axis=1))
    df2 = pd.concat(projection_dfs).reset_index(drop=True)
    if projection_tablename[i] == target_tablename:
        target_df = df2
    create_table_from_df(
        df2, ingest_schema, projection_tablename[i], ingest_engine, hive_bucket, hive_catalog, hive_schema, verbose=True
    )
# Out:
# drop table if exists demo_dv.itr_target_data
# /Users/michael/virtualenvs/itr-examples/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:225: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return _isna_array(np.asarray(obj), inf_as_na=inf_as_na)
# enforcing dataframe partition column order
#
# verifying existence of table demo_dv.itr_target_data
# create table if not exists demo_dv.itr_target_data (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     ei_s1_by_year double,
#     ei_s1_by_year_units varchar,
#     ei_s2_by_year double,
#     ei_s2_by_year_units varchar,
#     ei_s3_by_year double,
#     ei_s3_by_year_units varchar,
#     ei_s1s2_by_year double,
#     ei_s1s2_by_year_units varchar,
#     ei_s1s2s3_by_year double,
#     ei_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioning = array['year']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_bc56b732/_common_metadata  -->  trino/ingest/ingest_temp_bc56b732/_common_metadata
# /tmp/ingest_temp_bc56b732/_metadata  -->  trino/ingest/ingest_temp_bc56b732/_metadata
# /tmp/ingest_temp_bc56b732/year=2032/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2032/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2035/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2035/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2050/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2050/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2034/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2034/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2033/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2033/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2042/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2042/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2045/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2045/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2020/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2020/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2027/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2027/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2029/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2029/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2044/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2044/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2043/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2043/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2028/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2028/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2026/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2026/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2019/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2019/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2021/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2021/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2038/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2038/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2036/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2036/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2031/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2031/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2030/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2030/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2037/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2037/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2039/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2039/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2024/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2024/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2023/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2023/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2046/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2046/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2041/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2041/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2048/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2048/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2022/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2022/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2025/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2025/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2049/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2049/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2040/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2040/part.0.parquet
# /tmp/ingest_temp_bc56b732/year=2047/part.0.parquet  -->  trino/ingest/ingest_temp_bc56b732/year=2047/part.0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_bc56b732
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_bc56b732 (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     ei_s1_by_year double,
#     ei_s1_by_year_units varchar,
#     ei_s2_by_year double,
#     ei_s2_by_year_units varchar,
#     ei_s3_by_year double,
#     ei_s3_by_year_units varchar,
#     ei_s1s2_by_year double,
#     ei_s1s2_by_year_units varchar,
#     ei_s1s2s3_by_year double,
#     ei_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioned_by = array['year'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_bc56b732/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_bc56b732', 'FULL')
#
# overwriting data in demo_dv.itr_target_data
# delete from demo_dv.itr_target_data
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_bc56b732 -> demo_dv.itr_target_data
# insert into demo_dv.itr_target_data
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_bc56b732
# [(2432,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_bc56b732
# [{'ResponseMetadata': {'RequestId': 'V0PHHVNRRG4N036S', 'HostId': 'dvquGUrVN2V++SU+5rD4YG2PYoxOzDExuF2jNc1UfxGiJmHqU4CtxsVbwSnmj9okKjw+W9MHikw=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'dvquGUrVN2V++SU+5rD4YG2PYoxOzDExuF2jNc1UfxGiJmHqU4CtxsVbwSnmj9okKjw+W9MHikw=', 'x-amz-request-id': 'V0PHHVNRRG4N036S', 'date': 'Fri, 01 Dec 2023 02:12:14 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_bc56b732/year=2023/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2040/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/_common_metadata'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2030/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2049/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2027/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2037/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2044/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2042/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2033/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2035/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2047/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2019/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2050/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2025/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2038/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2026/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2032/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/_metadata'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2045/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2028/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2041/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2048/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2024/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2034/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2039/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2022/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2020/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2036/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2029/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2046/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2021/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2031/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_bc56b732/year=2043/part.0.parquet'}]}]
# drop table if exists demo_dv.itr_trajectory_data
# /Users/michael/virtualenvs/itr-examples/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:225: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return _isna_array(np.asarray(obj), inf_as_na=inf_as_na)
# enforcing dataframe partition column order
#
# verifying existence of table demo_dv.itr_trajectory_data
# create table if not exists demo_dv.itr_trajectory_data (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     ei_s1_by_year double,
#     ei_s1_by_year_units varchar,
#     ei_s2_by_year double,
#     ei_s2_by_year_units varchar,
#     ei_s3_by_year double,
#     ei_s3_by_year_units varchar,
#     ei_s1s2_by_year double,
#     ei_s1s2_by_year_units varchar,
#     ei_s1s2s3_by_year double,
#     ei_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioning = array['year']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_993003f0/_common_metadata  -->  trino/ingest/ingest_temp_993003f0/_common_metadata
# /tmp/ingest_temp_993003f0/_metadata  -->  trino/ingest/ingest_temp_993003f0/_metadata
# /tmp/ingest_temp_993003f0/year=2032/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2032/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2035/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2035/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2050/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2050/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2034/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2034/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2033/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2033/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2042/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2042/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2045/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2045/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2020/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2020/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2027/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2027/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2029/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2029/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2044/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2044/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2043/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2043/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2028/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2028/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2026/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2026/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2019/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2019/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2021/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2021/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2038/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2038/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2036/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2036/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2031/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2031/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2030/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2030/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2037/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2037/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2039/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2039/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2024/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2024/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2023/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2023/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2046/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2046/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2041/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2041/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2048/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2048/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2022/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2022/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2025/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2025/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2049/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2049/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2040/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2040/part.0.parquet
# /tmp/ingest_temp_993003f0/year=2047/part.0.parquet  -->  trino/ingest/ingest_temp_993003f0/year=2047/part.0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_993003f0
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_993003f0 (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     ei_s1_by_year double,
#     ei_s1_by_year_units varchar,
#     ei_s2_by_year double,
#     ei_s2_by_year_units varchar,
#     ei_s3_by_year double,
#     ei_s3_by_year_units varchar,
#     ei_s1s2_by_year double,
#     ei_s1s2_by_year_units varchar,
#     ei_s1s2s3_by_year double,
#     ei_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioned_by = array['year'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_993003f0/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_993003f0', 'FULL')
#
# overwriting data in demo_dv.itr_trajectory_data
# delete from demo_dv.itr_trajectory_data
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_993003f0 -> demo_dv.itr_trajectory_data
# insert into demo_dv.itr_trajectory_data
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_993003f0
# [(2432,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_993003f0
# [{'ResponseMetadata': {'RequestId': '8K98X6K6W2M3YQM9', 'HostId': 'en4UklCBZxzMUdVX7x6yL0fRi7YBd9kwCJW/ZCMOLHlojWPuhTLYQNgR6kBOYTM96zsb8teFVZ8=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'en4UklCBZxzMUdVX7x6yL0fRi7YBd9kwCJW/ZCMOLHlojWPuhTLYQNgR6kBOYTM96zsb8teFVZ8=', 'x-amz-request-id': '8K98X6K6W2M3YQM9', 'date': 'Fri, 01 Dec 2023 02:12:49 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_993003f0/year=2027/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2039/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2029/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2020/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2046/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2025/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/_common_metadata'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2036/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2041/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2049/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2034/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2019/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2030/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2033/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2035/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2037/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2021/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2040/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2023/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2024/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/_metadata'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2031/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2047/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2044/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2048/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2043/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2042/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2038/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2050/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2026/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2032/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2045/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2022/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_993003f0/year=2028/part.0.parquet'}]}]

# %%
osc._do_sql(f"select count (*) from {target_tablename}", ingest_engine, verbose=True)
osc._do_sql(f"select count (*) from {trajectory_tablename}", ingest_engine, verbose=True)
# Out:
# select count (*) from itr_target_data
# [(76,)]
# select count (*) from itr_trajectory_data
# [(76,)]
# [(76,)]

# %%
emissions_tablename = f"{itr_prefix}emissions_data"

# Create emissions_data table using production_df and math
emissions_df = production_df.merge(
    target_df.drop(columns=["company_name", "company_lei", "sector"]), on=["company_id", "year"]
)
emissions_df = emissions_df[
    ~emissions_df.company_id.isin(
        ["DE000SYM9999", "NO0010657505", "GB0000961622", "DE000BASF111", "IE00BZ12WP82", "FR0004024222"]
    )
]
print(emissions_df.index.names)
for scope in EScope.get_scopes():
    mask = emissions_df[f"ei_{scope.lower()}_by_year"].isna()
    emissions_df.loc[mask, f"ei_{scope.lower()}_by_year"] = emissions_df["production_by_year"].map(
        lambda x: Q_(np.nan, f"Mt CO2 / ({str(x.u)})")
    )
    emissions_df[f"co2_{scope.lower()}_by_year"] = (
        emissions_df["production_by_year"].mul(emissions_df[f"ei_{scope.lower()}_by_year"]).astype("pint[Mt CO2e]")
    )
    emissions_df = emissions_df.drop(columns=f"ei_{scope.lower()}_by_year")
emissions_df = emissions_df.drop(columns="production_by_year")
create_table_from_df(
    emissions_df,
    ingest_schema,
    emissions_tablename,
    ingest_engine,
    hive_bucket,
    hive_catalog,
    hive_schema,
    verbose=True,
)
# Out:
# [None]
# drop table if exists demo_dv.itr_emissions_data
# enforcing dataframe partition column order
#
# verifying existence of table demo_dv.itr_emissions_data
# create table if not exists demo_dv.itr_emissions_data (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     co2_s1_by_year double,
#     co2_s1_by_year_units varchar,
#     co2_s2_by_year double,
#     co2_s2_by_year_units varchar,
#     co2_s3_by_year double,
#     co2_s3_by_year_units varchar,
#     co2_s1s2_by_year double,
#     co2_s1s2_by_year_units varchar,
#     co2_s1s2s3_by_year double,
#     co2_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioning = array['year']
# )
#
# staging dataframe parquet to s3 osc-datacommons-s3-bucket-dev02
# /tmp/ingest_temp_e565ca02/_common_metadata  -->  trino/ingest/ingest_temp_e565ca02/_common_metadata
# /tmp/ingest_temp_e565ca02/_metadata  -->  trino/ingest/ingest_temp_e565ca02/_metadata
# /tmp/ingest_temp_e565ca02/year=2032/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2032/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2035/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2035/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2050/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2050/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2034/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2034/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2033/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2033/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2042/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2042/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2045/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2045/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2020/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2020/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2027/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2027/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2029/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2029/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2044/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2044/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2043/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2043/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2028/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2028/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2026/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2026/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2019/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2019/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2021/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2021/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2038/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2038/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2036/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2036/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2031/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2031/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2030/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2030/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2037/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2037/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2039/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2039/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2024/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2024/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2023/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2023/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2046/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2046/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2041/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2041/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2048/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2048/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2022/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2022/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2025/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2025/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2049/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2049/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2040/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2040/part.0.parquet
# /tmp/ingest_temp_e565ca02/year=2047/part.0.parquet  -->  trino/ingest/ingest_temp_e565ca02/year=2047/part.0.parquet
#
# declaring intermediate hive table osc_datacommons_hive_ingest.ingest.ingest_temp_e565ca02
# create table if not exists osc_datacommons_hive_ingest.ingest.ingest_temp_e565ca02 (
#     company_name varchar,
#     company_lei varchar,
#     company_id varchar,
#     sector varchar,
#     co2_s1_by_year double,
#     co2_s1_by_year_units varchar,
#     co2_s2_by_year double,
#     co2_s2_by_year_units varchar,
#     co2_s3_by_year double,
#     co2_s3_by_year_units varchar,
#     co2_s1s2_by_year double,
#     co2_s1s2_by_year_units varchar,
#     co2_s1s2s3_by_year double,
#     co2_s1s2s3_by_year_units varchar,
#     year bigint
# ) with (
#     format = 'parquet',
#     partitioned_by = array['year'],
#     external_location = 's3a://osc-datacommons-s3-bucket-dev02/trino/ingest/ingest_temp_e565ca02/'
# )
#
# syncing partition metadata on intermediate hive table
# call osc_datacommons_hive_ingest.system.sync_partition_metadata('ingest', 'ingest_temp_e565ca02', 'FULL')
#
# overwriting data in demo_dv.itr_emissions_data
# delete from demo_dv.itr_emissions_data
# [(None,)]
#
# transferring data: osc_datacommons_hive_ingest.ingest.ingest_temp_e565ca02 -> demo_dv.itr_emissions_data
# insert into demo_dv.itr_emissions_data
# select * from osc_datacommons_hive_ingest.ingest.ingest_temp_e565ca02
# [(2400,)]
#
# deleting table and data for intermediate table osc_datacommons_hive_ingest.ingest.ingest_temp_e565ca02
# [{'ResponseMetadata': {'RequestId': 'ECB6H5PW94SB2ZND', 'HostId': 'EyqlaqicNOD5TXq6yUC5xW2KT8AOUlJLedOmAie+TVxH70W4eU3v2i8DzzHeeYB+ZN0FggaN164=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'EyqlaqicNOD5TXq6yUC5xW2KT8AOUlJLedOmAie+TVxH70W4eU3v2i8DzzHeeYB+ZN0FggaN164=', 'x-amz-request-id': 'ECB6H5PW94SB2ZND', 'date': 'Fri, 01 Dec 2023 02:15:59 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3', 'connection': 'close'}, 'RetryAttempts': 0}, 'Deleted': [{'Key': 'trino/ingest/ingest_temp_e565ca02/year=2027/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2046/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/_common_metadata'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2044/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2035/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2041/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2028/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2045/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2026/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2037/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2043/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2047/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2049/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2034/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2022/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2033/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2040/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2048/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/_metadata'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2042/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2025/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2031/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2050/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2039/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2023/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2021/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2019/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2020/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2038/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2030/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2032/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2036/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2024/part.0.parquet'}, {'Key': 'trino/ingest/ingest_temp_e565ca02/year=2029/part.0.parquet'}]}]

# %%
emissions_df
# Out:
#            company_name           company_lei    company_id  \
# 0         SK Innovation  988400PXP70BWVSJVF07     096770.SK
# 1         SK Innovation  988400PXP70BWVSJVF07     096770.SK
# 2         SK Innovation  988400PXP70BWVSJVF07     096770.SK
# 3         SK Innovation  988400PXP70BWVSJVF07     096770.SK
# 4         SK Innovation  988400PXP70BWVSJVF07     096770.SK
# ...                 ...                   ...           ...
# 2427  Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
# 2428  Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
# 2429  Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
# 2430  Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
# 2431  Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
#
#                      sector  year           co2_s1_by_year  \
# 0                    Energy  2019       10.117595999999999
# 1                    Energy  2020       11.099542743700853
# 2                    Energy  2021        8.963148159254997
# 3                    Energy  2022        8.144233428818712
# 4                    Energy  2023        7.395703336263191
# ...                     ...   ...                      ...
# 2427  Electricity Utilities  2046        3.769433931712026
# 2428  Electricity Utilities  2047       2.7422371696791807
# 2429  Electricity Utilities  2048       1.7745981112853353
# 2430  Electricity Utilities  2049       0.8619305048286594
# 2431  Electricity Utilities  2050  -1.1329394619492559e-15
#
#           co2_s2_by_year      co2_s3_by_year        co2_s1s2_by_year  \
# 0               2.400554  151.79999999999998      12.518149999999999
# 1      2.733049295351212  131.46999999999997      12.093237999999998
# 2      2.501464925055745              118.35      10.899999999999999
# 3     2.2729195034693954  117.96502886698957      10.551102884701514
# 4     2.0640172585653014  117.58130997540924      10.213373585647398
# ...                  ...                 ...                     ...
# 2427                 0.0                 nan      2.1158195963480084
# 2428                 0.0                 nan      1.5127042549837622
# 2429                 0.0                 nan      0.9629449574412783
# 2430                 0.0                 nan      0.4604972513316361
# 2431                 0.0                 nan  -2.265878923898512e-15
#
#       co2_s1s2s3_by_year
# 0              164.31815
# 1     164.21174403905204
# 2     135.94506799515258
# 3      128.5161317516911
# 4     127.79468356105663
# ...                  ...
# 2427                 nan
# 2428                 nan
# 2429                 nan
# 2430                 nan
# 2431                 nan
#
# [2400 rows x 10 columns]
