# %% [markdown]
# # ITR Tool - Template Temperature Score Calculation
#
# This notebook provides a simple example of the ITR Toolkit as a means to evaluate Portfolio Alignment.  Text boxes (called Markdown cells) like this provide some explanation, and then code cells either do the work just explained or will do work that will be explained.
#
# All data needed to run this demonstration should be local and no acccess to the internet should be required.  However, if you want to delete a file and re-download it (to restore to its pristine state), of course you need access to the internet.
#
# The **Sample Data template** provides both a *Read me* sheet and sheet of data dictionary *Definitions*, as well as three input data sheets:
# * ITR input data: The fundamental financial, emissions, and production data of companies, listed by security instrument as company id
# * ITR target input data: Short-term Emissions or Intensity reduction targets and Net-Zero attainment target dates, listed by company id
# * Portfolio: A list of positions and investment value amounts
#
# The user may choose **Benchmark Data** that forecasts intensity reductions expected from 2020-2050 by region and sector.  By default we use the OECM benchmark, but two TPI benchmarks are also available.  In all three cases we use the same projections for production grwoth forecasts.  We also use the same global carbon budget and TCRE multipliers for all benchmarks.
#
# After scoring the portfolio, the portfolio is copied to the local file *data_dump.xlsx* which can be downloaded for further analysis.
#
# This notebook also outputs an **enhanced portfolio** (with temperature scores), can be aggregated using various weighting methods to gain additional portfolio alignment insights.
#
# Please enjoy learning how the ITR tool works by following the computations performed by this Jupyter Notebook!

# %% [markdown]
# ## Getting started
# Make sure you are running the notebook with the requirements installed available in the example folder.
#
# If you see errors when attempting to load the ITR modules, go to the top-level ITR directory, activate the `itr_env` conda environment (using `conda activate itr_env` and execute the command `pip install -e .`.  Then try again, or hit the <i class="fas fa-forward"></i> button above.

# %%
import os
import sys
import warnings

import json
import numpy as np
import pandas as pd

# %%
# Load the ITR library files

import ITR
from ITR import data_dir
from ITR.data.excel import ExcelProviderProductionBenchmark, ExcelProviderIntensityBenchmark
from ITR.data.template import TemplateProviderCompany
from ITR.data.base_providers import BaseProviderProductionBenchmark, BaseProviderIntensityBenchmark
from ITR.data.data_warehouse import DataWarehouse
from ITR.portfolio_aggregation import PortfolioAggregationMethod
from ITR.temperature_score import TemperatureScore
from ITR.interfaces import ETimeFrames, EScope, IProductionBenchmarkScopes, IEIBenchmarkScopes

from ITR.data.osc_units import ureg, Q_, PA_, asPintDataFrame, requantify_df_from_columns

from ITR_examples.utils import (
    plot_grouped_heatmap,
    plot_grouped_statistics,
    get_contributions_per_group,
    collect_company_contributions,
)

# %% [markdown]
# If all is well, the list of paths below will prioritize loading from the environment established for the ITR tool.  Please contact us if not.

# %%
print("Testing unit registry\n=====================")
one_co2 = ureg("CO2e")
print(f"The gas species CO2e, which was a gwp of 1: {one_co2}")

one_Gt_co2 = ureg("Gt CO2e")
print(f"A gigaton of CO2e: {one_Gt_co2}")
# Out:
# Testing unit registry
# =====================
# The gas species CO2e, which was a gwp of 1: 1 CO2e
# A gigaton of CO2e: 1 CO2e * gigametric_ton

# %% [markdown]
# ## Load the production and intensity benchmarks
#
# Prepare the various benchmark files; the OECM benchmark is the default after the next cell finishes.

# %%
benchmark_prod_json = os.path.join(data_dir, "benchmark_production_OECM.json")
benchmark_EI_OECM_PC = os.path.join(data_dir, "benchmark_EI_OECM_PC.json")
benchmark_EI_OECM_S3 = os.path.join(data_dir, "benchmark_EI_OECM_S3.json")
benchmark_EI_TPI = os.path.join(data_dir, "benchmark_EI_TPI_2_degrees.json")
benchmark_EI_TPI_below_2 = os.path.join(data_dir, "benchmark_EI_TPI_below_2_degrees.json")

# load production benchmarks
with open(benchmark_prod_json) as json_file:
    parsed_json = json.load(json_file)
prod_bms = IProductionBenchmarkScopes.model_validate(parsed_json)
base_production_bm = BaseProviderProductionBenchmark(production_benchmarks=prod_bms)

# load intensity benchmarks

# OECM
with open(benchmark_EI_OECM_S3) as json_file:
    parsed_json = json.load(json_file)
ei_bms = IEIBenchmarkScopes.model_validate(parsed_json)
OECM_EI_bm = BaseProviderIntensityBenchmark(EI_benchmarks=ei_bms)

if False:
    # OECM Production-Centric
    with open(benchmark_EI_OECM_PC) as json_file:
        parsed_json = json.load(json_file)
    ei_bms = IEIBenchmarkScopes.model_validate(parsed_json)
    OECM_EI_bm = BaseProviderIntensityBenchmark(EI_benchmarks=ei_bms)

    # TPI
    with open(benchmark_EI_TPI) as json_file:
        parsed_json = json.load(json_file)
    ei_bms = IEIBenchmarkScopes.model_validate(parsed_json)
    TPI_EI_bm = BaseProviderIntensityBenchmark(EI_benchmarks=ei_bms)

    # TPI below 2
    with open(benchmark_EI_TPI_below_2) as json_file:
        parsed_json = json.load(json_file)
    ei_bms = IEIBenchmarkScopes.model_validate(parsed_json)
    TPI_below_2_EI_bm = BaseProviderIntensityBenchmark(EI_benchmarks=ei_bms)

base_intensity_bm = OECM_EI_bm

# %% [markdown]
# ## Download/load the sample template data
#
# We have prepared sample data from public sources for you to be able to run the tool as it is to familiarise yourself with how it works. To use your own data; please check out to the [Data Template Requirements](https://github.com/os-c/ITR/blob/main/docs/DataTemplateRequirements.rst) section of the technical documentation for more details on data requirements and formatting.
#
# *The sample data may contain estimates, simplifications, and recategorizations.  It is intended to be generally representative, but not authoritative, and should not be relied upon to make investment decisions.*

# %%
template_data_path = os.path.abspath("../src/ITR_examples/data/20220927 ITR V2 Sample Data.xlsx")

# %% [markdown]
# ### Logging
# The ITR module uses the Python standard library logging utilities to send log messages. The log level can be changed according to the user's needs.

# %%
import logging

root_logger = logging.getLogger()
root_logger.setLevel("INFO")

# %% [markdown]
# ## Create a data provider
# Data providers let you connect to the data source of your choice. In this case we are connecting to Excel as a data provider for benchmark information and we are using the ITR Data Template for company and portfolio information, using *template_data_path* as the pathname to the data.  If you want to supply your own data file, you can set the pathname in the first line of the next cell.

# %%
# Remove the # and space on the next line to point the template_data_path variable at your own data
# template_data_path = "data/your_template_here.xlsx"

template_company_data = TemplateProviderCompany(excel_path=template_data_path)
# Out:
# 2023-11-03 07:55:53,285 - ITR.data.template - WARNING - Company DE0005190003 uses multiple units describing scopes ['s1', 's1s2', 's2', 's3']
# 2023-11-03 07:55:53,286 - ITR.data.template - WARNING - Company US00130H1059 uses multiple units describing scopes ['s1', 's1s2', 's2', 's3']
# 2023-11-03 07:55:53,286 - ITR.data.template - WARNING - The ITR Tool will choose one and covert all to that
# 2023-11-03 07:55:53,970 - ITR.data.template - WARNING - Emissions data missing for MultiIndex([('Energy', 'PETRONAS_SOE', 'S1'),
#             ('Energy', 'PETRONAS_SOE', 'S2')],
#            names=['sector', 'company_id', 'metric'])
# 2023-11-03 07:55:54,024 - ITR.data.template - WARNING - Scope 3 Emissions data missing for MultiIndex([('Construction Buildings', 'GB0000961622'),
#             ( 'Electricity Utilities', 'CA2908761018'),
#             ( 'Electricity Utilities', 'CA3495531079'),
#             ( 'Electricity Utilities', 'CA87807B1076'),
#             ( 'Electricity Utilities', 'US0185223007'),
#             ( 'Electricity Utilities', 'US0188021085'),
#             ( 'Electricity Utilities', 'US0236081024'),
#             ( 'Electricity Utilities', 'US0255371017'),
#             ( 'Electricity Utilities', 'US0921131092'),
#             ( 'Electricity Utilities', 'US1258961002'),
#             ( 'Electricity Utilities', 'US18551QAA58'),
#             ( 'Electricity Utilities', 'US2091151041'),
#             ( 'Electricity Utilities', 'US2333311072'),
#             ( 'Electricity Utilities', 'US25746U1097'),
#             ( 'Electricity Utilities', 'US26441C2044'),
#             ( 'Electricity Utilities', 'US29364G1031'),
#             ( 'Electricity Utilities', 'US30034W1062'),
#             ( 'Electricity Utilities', 'US30040W1080'),
#             ( 'Electricity Utilities', 'US30161N1019'),
#             ( 'Electricity Utilities', 'US3379321074'),
#             ( 'Electricity Utilities', 'US4198701009'),
#             ( 'Electricity Utilities', 'US5526901096'),
#             ( 'Electricity Utilities', 'US6362744095'),
#             ( 'Electricity Utilities', 'US65339F1012'),
#             ( 'Electricity Utilities', 'US65473P1057'),
#             ( 'Electricity Utilities', 'US6680743050'),
#             ( 'Electricity Utilities', 'US6708371033'),
#             ( 'Electricity Utilities', 'US69331C1080'),
#             ( 'Electricity Utilities', 'US69349H1077'),
#             ( 'Electricity Utilities', 'US69351T1060'),
#             ( 'Electricity Utilities', 'US7234841010'),
#             ( 'Electricity Utilities', 'US7365088472'),
#             ( 'Electricity Utilities', 'US7445731067'),
#             ( 'Electricity Utilities', 'US8168511090'),
#             ( 'Electricity Utilities', 'US8425871071'),
#             ( 'Electricity Utilities', 'US92939U1060'),
#             ( 'Electricity Utilities', 'US98389B1008'),
#             (                'Energy', 'PETRONAS_SOE'),
#             (                 'Steel', 'US1442851036'),
#             (                 'Steel', 'US2017231034'),
#             (                 'Steel', 'US3737371050'),
#             (                 'Steel', 'US8581191009'),
#             (                 'Steel', 'US9129091081'),
#             (                 'Steel', 'US9818111026')],
#            names=['sector', 'company_id'])
# 2023-11-03 07:55:54,631 - ITR.data.template - WARNING - Missing target start year set to 2021 for companies with ID: ['US0185223007', 'US0188021085', 'US0236081024', 'US0255371017', 'US05351W1036-E', 'US05351W1036-U', 'US0921131092', 'US1442851036', 'US18551QAA58', 'US25746U1097', 'US26441C2044', 'US30034W1062', 'US5526901096', 'JP3633400001']

# %% [raw]
# excel_production_bm = ExcelProviderProductionBenchmark(excel_path="data/OECM_EI_and_production_benchmarks.xlsx")

# %% [raw]
# excel_EI_bm = ExcelProviderIntensityBenchmark(excel_path="data/OECM_EI_and_production_benchmarks.xlsx",
#                                               benchmark_temperature=Q_(1.5, ureg.delta_degC),
#                                               benchmark_global_budget=396 * ureg('Gt CO2'),
#                                               is_AFOLU_included=False)

# %% [markdown]
# ## Create the Data Warehouse

# %%
template_company_data._companies[0].production_metric
# Out:
# 'GWh'

# %%
template_provider = DataWarehouse(
    template_company_data,
    base_production_bm,
    base_intensity_bm,
    estimate_missing_data=DataWarehouse.estimate_missing_s3_data,
)

# Fills in template_company_data._companies[0].projected_targets.S1S2

print(
    f"Benchmark Temperature = {base_intensity_bm.benchmark_temperature}\n\
Benchmark Global Budget = {base_intensity_bm.benchmark_global_budget}\n\
AFOLU included = {base_intensity_bm.is_AFOLU_included}"
)
# Out:
# 2023-11-03 07:55:57,018 - ITR.data.data_warehouse - INFO - new_production_bm calculating trajectories for 76 companies (times 5 scopes times 31 years)
# 2023-11-03 07:55:59,054 - ITR.data.base_providers - INFO - Normalizing intensity metrics
# 2023-11-03 07:55:59,201 - ITR.data.base_providers - INFO - Done normalizing intensity metrics
# 2023-11-03 07:55:59,202 - ITR.data.data_warehouse - INFO - estimating missing data
# 2023-11-03 07:55:59,204 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0185223007 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,207 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0188021085 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,210 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0236081024 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,212 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0255371017 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,215 - ITR.data.data_warehouse - INFO - Added S3 estimates for US0921131092 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,219 - ITR.data.data_warehouse - INFO - Added S3 estimates for US1442851036 (sector = Steel, region = North America)
# 2023-11-03 07:55:59,221 - ITR.data.data_warehouse - INFO - Added S3 estimates for US1258961002 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,224 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2017231034 (sector = Steel, region = North America)
# 2023-11-03 07:55:59,227 - ITR.data.data_warehouse - INFO - Added S3 estimates for US18551QAA58 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,230 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2091151041 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,232 - ITR.data.data_warehouse - INFO - Added S3 estimates for US2333311072 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,236 - ITR.data.data_warehouse - INFO - Added S3 estimates for US25746U1097 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,238 - ITR.data.data_warehouse - INFO - Added S3 estimates for US26441C2044 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,241 - ITR.data.data_warehouse - INFO - Added S3 estimates for US29364G1031 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,243 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30034W1062 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,247 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30040W1080 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,249 - ITR.data.data_warehouse - INFO - Added S3 estimates for US30161N1019 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,252 - ITR.data.data_warehouse - INFO - Added S3 estimates for US3379321074 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,254 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA3495531079 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,257 - ITR.data.data_warehouse - INFO - Added S3 estimates for US3737371050 (sector = Steel, region = Global)
# 2023-11-03 07:55:59,260 - ITR.data.data_warehouse - INFO - Added S3 estimates for US4198701009 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,263 - ITR.data.data_warehouse - INFO - Added S3 estimates for US5526901096 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,267 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6362744095 (sector = Electricity Utilities, region = Europe)
# 2023-11-03 07:55:59,270 - ITR.data.data_warehouse - INFO - Added S3 estimates for US65339F1012 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,272 - ITR.data.data_warehouse - INFO - Added S3 estimates for US65473P1057 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,275 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6680743050 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,277 - ITR.data.data_warehouse - INFO - Added S3 estimates for US6708371033 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,281 - ITR.data.data_warehouse - INFO - Added S3 estimates for PETRONAS_SOE (sector = Energy, region = Global)
# 2023-11-03 07:55:59,284 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69331C1080 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,286 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69349H1077 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,289 - ITR.data.data_warehouse - INFO - Added S3 estimates for US69351T1060 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,291 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7234841010 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,294 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7365088472 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,297 - ITR.data.data_warehouse - INFO - Added S3 estimates for US7445731067 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,300 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8168511090 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,303 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8425871071 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,306 - ITR.data.data_warehouse - INFO - Added S3 estimates for US8581191009 (sector = Steel, region = North America)
# 2023-11-03 07:55:59,308 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA87807B1076 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,312 - ITR.data.data_warehouse - INFO - Added S3 estimates for US9129091081 (sector = Steel, region = North America)
# 2023-11-03 07:55:59,314 - ITR.data.data_warehouse - INFO - Added S3 estimates for CA2908761018 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,317 - ITR.data.data_warehouse - INFO - Added S3 estimates for US92939U1060 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,320 - ITR.data.data_warehouse - INFO - Added S3 estimates for US9818111026 (sector = Steel, region = North America)
# 2023-11-03 07:55:59,322 - ITR.data.data_warehouse - INFO - Added S3 estimates for US98389B1008 (sector = Electricity Utilities, region = North America)
# 2023-11-03 07:55:59,326 - ITR.data.data_warehouse - INFO - Added S3 estimates for GB0000961622 (sector = Construction Buildings, region = Europe)
# 2023-11-03 07:55:59,327 - ITR.data.data_warehouse - INFO - projecting targets for 76 companies (times 5 scopes times 31 years)
# Benchmark Temperature = 1.5 delta_degree_Celsius
# Benchmark Global Budget = 521.0526315789474 CO2 * gigametric_ton
# AFOLU included = False

# %%
ureg("kg CO2/(passenger km)")
# Out:
# 1.0 <Unit('CO2 * kilogram / pkm')>

# %% [markdown]
# ## Load your portfolio
#
# The portfolio data is a sheet in the Data Template named "Portfolio".
#
# Please see the technical documentation in the [Data Template Requirements](https://github.com/os-c/ITR/blob/main/docs/DataTemplateRequirements.rst) section for details on data requirements.

# %%
df_portfolio = requantify_df_from_columns(pd.read_excel(template_data_path, sheet_name="Portfolio"))
display(df_portfolio.tail())
# Out:
#                   company_name           company_lei    company_id  \
# 71            WEC Energy Group  549300IGLYTZUK3PVP70  US92939U1060
# 72  WORTHINGTON INDUSTRIES INC  1WRCIANKYOIK6KYE5E82  US9818111026
# 73           Xcel Energy, Inc.  LGJNMI9GH8XIDG5RCM61  US98389B1008
# 74              Balfour Beatty  CT4UIJ3TUKGYYHMENQ17  GB0000961622
# 75                        CBRE  52990016II9MJ2OSWA10  US12504L1098
#
#     company_isin  investment_value
# 71  US92939U1060         156078372
# 72  US9818111026         150599095
# 73  US98389B1008         145984384
# 74  GB0000961622          94590720
# 75  US12504L1098          50391328

# %% [markdown]
# To load the data from the data provider, we have to pass a list of IPortfolioCompany instances. The module has a strict [data model](https://ofbdabv.github.io/ITR/autoapi/ITR/interfaces/index.html) to convert Pandas Dataframe to the right object types we supplied a utility function.

# %%
companies = ITR.utils.dataframe_to_portfolio(df_portfolio)

# %% [markdown]
# ## Calculate the temperature scores
# In the enhanced portfolio you'll find your original portfolio, with calculated temperature scores, trajectory and target scores and overshoot/undershoot ration, and a temperature_result which is current set to zero for all valid calculations.

# %%
temperature_score_s1s2s3 = TemperatureScore(
    time_frames=[ETimeFrames.LONG],
    scopes=[EScope.S1S2S3],
    aggregation_method=PortfolioAggregationMethod.WATS,  # Options for the aggregation method are WATS, TETS, AOTS, MOTS, EOTS, ECOTS, and ROTS.
)
enhanced_portfolio = temperature_score_s1s2s3.calculate(data_warehouse=template_provider, portfolio=companies)
# Out:
# 2023-11-03 07:56:01,017 - ITR.temperature_score - INFO - calculating temperature score for 76 companies
# 2023-11-03 07:56:07,424 - ITR.temperature_score - INFO - temperature score preparing data
# 2023-11-03 07:56:07,525 - ITR.temperature_score - INFO - temperature score data prepared

# %% [markdown]
# For every company the tool assigns a score for all the requested timeframe and scope combinations. For now the ITR methodolgy only supportt a long timeframe in combination with a S1S2 scope

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    display(enhanced_portfolio[["company_name", "time_frame", "scope", "temperature_score"]])
# Out:
#                                    company_name time_frame   scope  \
# company_id
# US00130H1059                          AES Corp.       LONG  S1S2S3
# US0185223007                       ALLETE, Inc.       LONG  S1S2S3
# US0188021085                     Alliant Energy       LONG  S1S2S3
# US0236081024                       Ameren Corp.       LONG  S1S2S3
# US0255371017  American Electric Power Co., Inc.       LONG  S1S2S3
# ...                                         ...        ...     ...
# US92939U1060                   WEC Energy Group       LONG  S1S2S3
# US9818111026         WORTHINGTON INDUSTRIES INC       LONG  S1S2S3
# US98389B1008                  Xcel Energy, Inc.       LONG  S1S2S3
# GB0000961622                     Balfour Beatty       LONG  S1S2S3
# US12504L1098                               CBRE       LONG  S1S2S3
#
#                temperature_score
# company_id
# US00130H1059  1.9511764615162877
# US0185223007  3.5202340077128333
# US0188021085   2.251433843906471
# US0236081024   4.473414472707755
# US0255371017  3.7259694918985873
# ...                          ...
# US92939U1060   3.186000629173453
# US9818111026   1.597149767977132
# US98389B1008   2.483338529630434
# GB0000961622  1.5555503716708488
# US12504L1098   2.547038159930691
#
# [76 rows x 4 columns]

# %%
data = enhanced_portfolio[
    (enhanced_portfolio.scope == EScope.S1S2S3) & (enhanced_portfolio.temperature_score > Q_(3, "delta_degC"))
]
data
# Out:
#                scope                        company_name  \
# company_id
# US0185223007  S1S2S3                        ALLETE, Inc.
# US0236081024  S1S2S3                        Ameren Corp.
# US0255371017  S1S2S3   American Electric Power Co., Inc.
# US0921131092  S1S2S3                   Black Hills Corp.
# US1258961002  S1S2S3                    CMS Energy Corp.
# US18551QAA58  S1S2S3                   Cleco Partners LP
# US2091151041  S1S2S3           Consolidated Edison, Inc.
# US2333311072  S1S2S3                          DTE Energy
# FR0010242511  S1S2S3               Electricité de France
# US30034W1062  S1S2S3                        Evergy, Inc.
# US4198701009  S1S2S3  Hawaiian Electric Industries, Inc.
# US5526901096  S1S2S3                 MDU Resources Group
# US6362744095  S1S2S3                   National Grid PLC
# JP3381000003  S1S2S3                   NIPPON STEEL CORP
# US65473P1057  S1S2S3                       Nisource Inc.
# US6708371033  S1S2S3                   OG&E Energy Corp.
# US69349H1077  S1S2S3                 PNM Resources, Inc.
# US69351T1060  S1S2S3                           PPL Corp.
# US7234841010  S1S2S3         Pinnacle West Capital Corp.
# US8168511090  S1S2S3                              Sempra
# CA87807B1076  S1S2S3                     TC Energy Corp.
# US92840M1027  S1S2S3                        Vistra Corp.
# US92939U1060  S1S2S3                    WEC Energy Group
#
#                              sector         region  target_probability  \
# company_id
# US0185223007  Electricity Utilities  North America                 0.5
# US0236081024  Electricity Utilities  North America                 0.5
# US0255371017  Electricity Utilities  North America                 0.5
# US0921131092  Electricity Utilities  North America                 0.5
# US1258961002  Electricity Utilities  North America                 0.5
# US18551QAA58  Electricity Utilities  North America                 0.5
# US2091151041  Electricity Utilities  North America                 0.5
# US2333311072  Electricity Utilities  North America                 0.5
# FR0010242511  Electricity Utilities         Europe                 0.5
# US30034W1062  Electricity Utilities  North America                 0.5
# US4198701009  Electricity Utilities  North America                 0.5
# US5526901096  Electricity Utilities  North America                 0.5
# US6362744095  Electricity Utilities         Europe                 0.5
# JP3381000003                  Steel           Asia                 0.5
# US65473P1057  Electricity Utilities  North America                 0.5
# US6708371033  Electricity Utilities  North America                 0.5
# US69349H1077  Electricity Utilities  North America                 0.5
# US69351T1060  Electricity Utilities  North America                 0.5
# US7234841010  Electricity Utilities  North America                 0.5
# US8168511090  Electricity Utilities  North America                 0.5
# CA87807B1076  Electricity Utilities  North America                 0.5
# US92840M1027  Electricity Utilities  North America                 0.5
# US92939U1060  Electricity Utilities  North America                 0.5
#
#                                                     target_data  \
# company_id
# US0185223007  [netzero_year=2050 target_type='absolute' targ...
# US0236081024  [netzero_year=2050 target_type='absolute' targ...
# US0255371017  [netzero_year=2050 target_type='absolute' targ...
# US0921131092  [netzero_year=None target_type='intensity' tar...
# US1258961002  [netzero_year=None target_type='absolute' targ...
# US18551QAA58  [netzero_year=2050 target_type='absolute' targ...
# US2091151041  [netzero_year=2040 target_type='absolute' targ...
# US2333311072  [netzero_year=2050 target_type='absolute' targ...
# FR0010242511  [netzero_year=2050 target_type='absolute' targ...
# US30034W1062  [netzero_year=2045 target_type='absolute' targ...
# US4198701009  [netzero_year=None target_type='intensity' tar...
# US5526901096  [netzero_year=None target_type='intensity' tar...
# US6362744095  [netzero_year=2050 target_type='absolute' targ...
# JP3381000003  [netzero_year=2050 target_type='absolute' targ...
# US65473P1057  [netzero_year=2050 target_type='absolute' targ...
# US6708371033  [netzero_year=None target_type='absolute' targ...
# US69349H1077  [netzero_year=2040 target_type='absolute' targ...
# US69351T1060  [netzero_year=2050 target_type='absolute' targ...
# US7234841010  [netzero_year=2050 target_type='absolute' targ...
# US8168511090  [netzero_year=2050 target_type='intensity' tar...
# CA87807B1076  [netzero_year=2050 target_type='intensity' tar...
# US92840M1027  [netzero_year=2050 target_type='absolute' targ...
# US92939U1060  [netzero_year=2050 target_type='intensity' tar...
#
#                                                   historic_data country  \
# company_id
# US0185223007  productions=[IProductionRealization(year=2016,...      US
# US0236081024  productions=[IProductionRealization(year=2016,...      US
# US0255371017  productions=[IProductionRealization(year=2016,...      US
# US0921131092  productions=[IProductionRealization(year=2016,...      US
# US1258961002  productions=[IProductionRealization(year=2016,...      US
# US18551QAA58  productions=[IProductionRealization(year=2016,...      US
# US2091151041  productions=[IProductionRealization(year=2016,...      US
# US2333311072  productions=[IProductionRealization(year=2016,...      US
# FR0010242511  productions=[IProductionRealization(year=2016,...      FR
# US30034W1062  productions=[IProductionRealization(year=2016,...      US
# US4198701009  productions=[IProductionRealization(year=2016,...      US
# US5526901096  productions=[IProductionRealization(year=2016,...      US
# US6362744095  productions=[IProductionRealization(year=2016,...      GB
# JP3381000003  productions=[IProductionRealization(year=2016,...      JP
# US65473P1057  productions=[IProductionRealization(year=2016,...      US
# US6708371033  productions=[IProductionRealization(year=2016,...      US
# US69349H1077  productions=[IProductionRealization(year=2016,...      US
# US69351T1060  productions=[IProductionRealization(year=2016,...      US
# US7234841010  productions=[IProductionRealization(year=2016,...      US
# US8168511090  productions=[IProductionRealization(year=2016,...      US
# CA87807B1076  productions=[IProductionRealization(year=2016,...      CA
# US92840M1027  productions=[IProductionRealization(year=2016,...      US
# US92939U1060  productions=[IProductionRealization(year=2016,...      US
#
#              emissions_metric production_metric  ... target_exceedance_year  \
# company_id                                       ...
# US0185223007          Mt CO2e               TWh  ...                 2019.0
# US0236081024          Mt CO2e               TWh  ...                 2019.0
# US0255371017          Mt CO2e               TWh  ...                 2019.0
# US0921131092           t CO2e               MWh  ...                 2019.0
# US1258961002          Mt CO2e               TWh  ...                 2019.0
# US18551QAA58          Mt CO2e               TWh  ...                 2019.0
# US2091151041          Mt CO2e               TWh  ...                 2019.0
# US2333311072          Mt CO2e               TWh  ...                 2019.0
# FR0010242511          Mt CO2e               GWh  ...                 2019.0
# US30034W1062          Mt CO2e               TWh  ...                 2019.0
# US4198701009          Mt CO2e               TWh  ...                 2019.0
# US5526901096          Mt CO2e               TWh  ...                 2019.0
# US6362744095          Mt CO2e               TWh  ...                 2019.0
# JP3381000003           t CO2e           Steel·t  ...                 2019.0
# US65473P1057          Mt CO2e               TWh  ...                 2019.0
# US6708371033           t CO2e               MWh  ...                 2019.0
# US69349H1077          Mt CO2e               TWh  ...                 2019.0
# US69351T1060          Mt CO2e               TWh  ...                 2019.0
# US7234841010          Mt CO2e               TWh  ...                 2019.0
# US8168511090          Mt CO2e               TWh  ...                 2019.0
# CA87807B1076          Mt CO2e               TWh  ...                 2019.0
# US92840M1027          Mt CO2e               TWh  ...                 2019.0
# US92939U1060          Mt CO2e               TWh  ...                 2019.0
#
#               company_isin  investment_value time_frame   temperature_score  \
# company_id
# US0185223007  US0185223007         269631356       LONG  3.5202340077128333
# US0236081024  US0236081024          93011236       LONG   4.473414472707755
# US0255371017  US0255371017         176602242       LONG  3.7259694918985873
# US0921131092  US0921131092         243360405       LONG  3.0486567675371825
# US1258961002  US1258961002         120827925       LONG   4.639153535086694
# US18551QAA58  US18551QAA58         202777551       LONG   4.968912274661995
# US2091151041  US2091151041         175585595       LONG   3.314435159751554
# US2333311072  US2333311072         136659250       LONG   7.291605657906049
# FR0010242511  FR0010242511         190510040       LONG   4.191830879848466
# US30034W1062  US30034W1062          47505810       LONG   3.165417538707774
# US4198701009  US4198701009          63644256       LONG   5.704245266403902
# US5526901096  US5526901096          84898865       LONG   5.160257989832029
# US6362744095  US6362744095          71104363       LONG   3.857862478011334
# JP3381000003  JP3381000003         162437640       LONG  3.1684826786822455
# US65473P1057  US65473P1057         145931695       LONG   4.367797098309684
# US6708371033  US6708371033          94289416       LONG   4.769724148369069
# US69349H1077  US69349H1077          84068718       LONG  3.4435969156990103
# US69351T1060  US69351T1060         205713830       LONG       5.28690947864
# US7234841010  US7234841010         146411528       LONG  3.2958009123191037
# US8168511090  US8168511090         175262934       LONG   3.296979685816029
# CA87807B1076  CA87807B1076         119808972       LONG   4.569896063096689
# US92840M1027  US92840M1027         141152100       LONG   4.294912411236757
# US92939U1060  US92939U1060         156078372       LONG   3.186000629173453
#
#                 trajectory_score trajectory_overshoot_ratio  \
# company_id
# US0185223007  3.5202340077128333           7.45732831409259
# US0236081024   4.473414472707755          10.50400468007452
# US0255371017  3.7259694918985873          8.114926177594675
# US0921131092  3.0486567675371825          5.950013293336478
# US1258961002   4.639153535086694         11.033760904435045
# US18551QAA58   4.968912274661995         12.087777636036243
# US2091151041   3.314435159751554          6.799527919249962
# US2333311072   7.291605657906049         19.511864989935145
# FR0010242511   4.464312594747323         10.474912102659761
# US30034W1062   3.165417538707774          6.323218887726372
# US4198701009   5.704245266403902         14.438142261982277
# US5526901096   5.160257989832029         12.699381093670638
# US6362744095   3.857862478011334          8.536499277742745
# JP3381000003  3.1684826786822455          6.333016077095648
# US65473P1057   4.367797098309684          10.16641702460638
# US6708371033   4.769724148369069         11.451107268726405
# US69349H1077  3.4435969156990103          7.212371114935826
# US69351T1060       5.28690947864         13.104200654958778
# US7234841010  3.2958009123191037          6.739966772819408
# US8168511090   3.296979685816029          6.743734518263024
# CA87807B1076   4.569896063096689          10.81239138331217
# US92840M1027   4.294912411236757          9.933453738322227
# US92939U1060   3.186000629173453           6.38900917357847
#
#                    target_score  target_overshoot_ratio  score_result_type
# company_id
# US0185223007                nan                     nan    TRAJECTORY_ONLY
# US0236081024                nan                     nan    TRAJECTORY_ONLY
# US0255371017                nan                     nan    TRAJECTORY_ONLY
# US0921131092                nan                     nan    TRAJECTORY_ONLY
# US1258961002                nan                     nan    TRAJECTORY_ONLY
# US18551QAA58                nan                     nan    TRAJECTORY_ONLY
# US2091151041                nan                     nan    TRAJECTORY_ONLY
# US2333311072                nan                     nan    TRAJECTORY_ONLY
# FR0010242511  4.191830879848466       9.603971466094158        TARGET_ONLY
# US30034W1062                nan                     nan    TRAJECTORY_ONLY
# US4198701009                nan                     nan    TRAJECTORY_ONLY
# US5526901096                nan                     nan    TRAJECTORY_ONLY
# US6362744095                nan                     nan    TRAJECTORY_ONLY
# JP3381000003                nan                     nan    TRAJECTORY_ONLY
# US65473P1057                nan                     nan    TRAJECTORY_ONLY
# US6708371033                nan                     nan    TRAJECTORY_ONLY
# US69349H1077                nan                     nan    TRAJECTORY_ONLY
# US69351T1060                nan                     nan    TRAJECTORY_ONLY
# US7234841010                nan                     nan    TRAJECTORY_ONLY
# US8168511090                nan                     nan    TRAJECTORY_ONLY
# CA87807B1076                nan                     nan    TRAJECTORY_ONLY
# US92840M1027                nan                     nan    TRAJECTORY_ONLY
# US92939U1060                nan                     nan    TRAJECTORY_ONLY
#
# [23 rows x 42 columns]

# %% [markdown]
# ## Calculate the aggregated temperature score
# Calculate an aggregated temperature score. This can be done using different aggregation methods. Here we'll use the "Weighted Average Temperature Score" (WATS) by initializing the TemperatureScore Object with PortfolioAggregationMethod.WATS. The temperature scores are calculated per time-frame/scope combination.

# %%
aggregated_scores = temperature_score_s1s2s3.aggregate_scores(enhanced_portfolio)
print(f"Temperature Score aggregation method = {temperature_score_s1s2s3.aggregation_method}")
# Out:
# Temperature Score aggregation method = PortfolioAggregationMethod.WATS

# %%
aggregated_scores.long.S1S2S3.all.score
# Out:
# 2.680138894037355 <Unit('delta_degree_Celsius')>

# %% [markdown]
# ## Display aggregation data in various ways

# %% [markdown]
# The first analysis of your portfolio could be to understand if you have any particular hotspots in your portfolio. We can do that by analysing different groupings of companies.
#
# The tool allows you to calculate temperature scores for _groups_ of companies. In this example we group the scores by sector and region, and leave the timeframe and scope unchanged. Any categorical variable in the data provided by you or your data provider (in the `test_company_data.xlsx` imported above) can be used as grouping variable, e.g. sectors, industries, regions, countries, market cap buckets, as well as the additional fields you imported via the portfolio data.
#
# You can change the variable by which the data is grouped by replacing the fourth line in the following cell. For example, replacing "grouping=['sector', 'region']" by "grouping=['sector', 'country']" would result in temperature scores per sector per country.
# If you want to change the time frame as well, please refer to the section 'Calculate the company temperature scores' above.

# %%
grouping = ["sector", "region"]
temperature_score_s1s2s3.grouping = grouping
grouped_portfolio = temperature_score_s1s2s3.calculate(data_warehouse=template_provider, portfolio=companies)
grouped_aggregations = temperature_score_s1s2s3.aggregate_scores(grouped_portfolio)
# Out:
# 2023-11-03 07:56:07,927 - ITR.temperature_score - INFO - calculating temperature score for 76 companies
# 2023-11-03 07:56:14,225 - ITR.temperature_score - INFO - temperature score preparing data
# 2023-11-03 07:56:14,321 - ITR.temperature_score - INFO - temperature score data prepared

# %% [markdown]
# The aggregated scores can then be used, for example, to show the relation between sectors and regions with respect to temperature score.
# A visualization of this relation is shown in the heatmap below. The grey fields indicate that the portfolio contains no assest for those combinations.
#
# #### Quick analysis: Heat Map
#
# We can see here that our North American Steel is in reasonable shape. While Asian Steel can be improved as shown in the drill down below the graph

# %%
analysis_parameters = ([ETimeFrames.LONG], [EScope.S1S2S3], grouping)
plot_grouped_heatmap(grouped_aggregations, analysis_parameters)

# %%
region = "Europe"
sector = "Steel"
group = sector + "-" + region
analysis_parameters = ([ETimeFrames.LONG], [EScope.S1S2S3], grouping)
group_contributions = get_contributions_per_group(grouped_aggregations, analysis_parameters, group)
group_contributions.round(2)
# Out:
#           group  company_name    company_id  \
# 0  Steel-Europe    TENARIS SA  US88031M1099
# 1  Steel-Europe  TERNIUM S.A.  US8808901081
#
#                          temperature_score      contribution_relative
# 0  1.6912879763614752 delta_degree_Celsius  60.78670766981185 percent
# 1   2.035927773982995 delta_degree_Celsius  39.21329233018816 percent

# %% [markdown]
# #### Sector analysis
#
# Sector analysis may help us with bringing some clarity into our analysis from the heatmap above. In order to identify the companies that your portfolio would most benefit from engaging with, we can start with identifying the biggest contributing sectors to the portfolio's temperature score, as in our example below.
#
# Contributions can be identified on an individual company level, as well as contributions from companies grouped by one of their characteristics, e.g. sector or region. The exact definitions of companies' contributions to the portfolio temperature scores depend on the selected aggregation method.
#
# You can group companies on any categorical variable (e.g. sectors, countries, market cap buckets, investment strategies, etc)  you provide through your dataprovider, in this example in the test_company_data.xlsx imported above.
#
# For our analysis we select one time-frame (LONG) and one scope (S1+S2) and group the outcomes on sector and compare AUM to temperature score contribution. We also then display the sector temperature scores.
#
# #### Quick analysis
#
# In this example we can see that both sectors Steel and Electricity are scoring above 2.0C.

# %%
time_frames = [ETimeFrames.LONG]
scopes = [EScope.S1S2, EScope.S3]
grouping = ["sector"]
analysis_parameters = (time_frames, scopes, grouping)

temperature_score_s1s2_s3 = TemperatureScore(
    time_frames=time_frames, scopes=scopes, grouping=grouping, aggregation_method=PortfolioAggregationMethod.WATS
)
enhanced_portfolio = temperature_score_s1s2_s3.calculate(data_warehouse=template_provider, portfolio=companies)
aggregated_portfolio = temperature_score_s1s2_s3.aggregate_scores(enhanced_portfolio)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    company_contributions = collect_company_contributions(aggregated_portfolio, enhanced_portfolio, analysis_parameters)
# Out:
# 2023-11-03 07:56:15,304 - ITR.temperature_score - INFO - calculating temperature score for 76 companies
# 2023-11-03 07:56:21,607 - ITR.temperature_score - INFO - temperature score preparing data
# 2023-11-03 07:56:21,677 - ITR.temperature_score - INFO - temperature score data prepared

# %%
plot_grouped_statistics(
    aggregated_portfolio, company_contributions.pint.dequantify().droplevel(level=1, axis=1), analysis_parameters
)

# %% [markdown]
# We can use what we learned from this analysis to drill into a few of the highest contributing scoring sectors to see which
# companies are the biggest contributors on the sector level. Considering the Steel sector, for instance, in the
# table below.

# %%
sector_contributions = company_contributions[
    [
        "company_name",
        "company_id",
        "sector",
        "contribution",
        "temperature_score",
        "ownership_percentage",
        "portfolio_percentage",
    ]
]
asPintDataFrame(sector_contributions[sector_contributions["sector"] == "Steel"][:10]).pint.dequantify().round(2)
# Out:
#                    company_name    company_id  sector contribution  \
# unit                    No Unit       No Unit No Unit      percent
# 5     CARPENTER TECHNOLOGY CORP  US1442851036   Steel          3.1
# 4     CARPENTER TECHNOLOGY CORP  US1442851036   Steel          3.1
# 13            NIPPON STEEL CORP  JP3381000003   Steel         2.27
# 12            NIPPON STEEL CORP  JP3381000003   Steel         2.27
# 49             TIMKENSTEEL CORP  US8873991033   Steel         1.62
# 48             TIMKENSTEEL CORP  US8873991033   Steel         1.62
# 51     UNITED STATES STEEL CORP  US9129091081   Steel         1.55
# 50     UNITED STATES STEEL CORP  US9129091081   Steel         1.55
# 58                   TENARIS SA  US88031M1099   Steel         1.37
# 59                   TENARIS SA  US88031M1099   Steel         1.37
#
#         temperature_score ownership_percentage portfolio_percentage
# unit delta_degree_Celsius        dimensionless        dimensionless
# 5                    4.07                 9.89                 0.39
# 4                    4.07                 9.89                 0.39
# 13                   3.06                 1.99                 0.38
# 12                   3.06                 1.99                 0.38
# 49                   1.52                69.02                 0.55
# 48                   1.52                69.02                 0.55
# 51                    1.8                 7.24                 0.44
# 50                    1.8                 7.24                 0.44
# 58                   2.17                23.43                 0.32
# 59                   2.17                23.43                 0.32

# %% [markdown]
# ### Save portfolio data for further analysis
# To take your analysis outside of this notebook and for example for internal and client reporting, you can export all data to Excel and the clipboard for pasting into and analysing in other applications.
#
# If you run the ITR tool locally or from Google Colab, you:
# - Specify the filenames of the output files in the cell below, e.g. change 'data_dump.xlsx' in the first line to 'TS_output.xlsx'
# - Run the cell below

# %%
data_dump_filename = "data_dump.xlsx"
enhanced_portfolio.set_index(["company_name"], append=True).to_excel(data_dump_filename)

# %%
data_dump_filename = "data_dump_dequantified.xlsx"
enhanced_portfolio.set_index(["company_name"], append=True).pint.dequantify().to_excel(data_dump_filename)

# %% [markdown]
# ### Compare OECD and non-OECD results
#
# There are currently 37 members of the OECD (text list maintained on the OECD website).  We use a simple CSV file containing data correct as of June 6th, 2022.

# %%
from ITR.utils import get_project_root

pkg_root = get_project_root()

# When connected to the Data Commons, this would be the kind of data we could simply load from a table.
# As this is a stand-alone program, we must load the data from a file.

oecd_df = pd.read_csv(f"{pkg_root}/data/input/oecd_iso.csv")

# %% [markdown]
# We reuse the calculated `grouped_portfolio` from above, and then add the additional OECD discriminator to it.  We can add arbitrary columns and group on them in this way.  (And of course we can recompute a fresh `grouped_portfolio` if we wish.)
#
# Because of the way we generate grouped and aggregated data (which uses dash (-) as a separator), we spell Non-OECD with an underscore  (non_oecd) instead of a dash.

# %%
grouping = ["sector", "oecd"]
grouped_portfolio.loc[:, "oecd"] = grouped_portfolio.country.map(
    lambda x: "oecd" if x in oecd_df.alpha_2.values else "non_oecd"
)
temperature_score_s1s2s3.grouping = grouping
grouped_aggregations = temperature_score_s1s2s3.aggregate_scores(grouped_portfolio)
analysis_parameters = ([ETimeFrames.LONG], [EScope.S1S2S3], grouping)
plot_grouped_heatmap(grouped_aggregations, analysis_parameters)
